# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CoderSoham345/flyrankmlinternship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My lane

I selected **Lane 1 – Ranking Signal Analysis** because I want to understand which content characteristics and search signals influence page visibility and engagement. This lane helps identify patterns that can improve search performance and support better content decisions. Instead of simply building a machine learning model, the goal is to understand the relationship between content features and ranking signals so future recommendations are meaningful and actionable.
# Out:
#   Cell In[2], line 3
#     I selected **Lane 1 – Ranking Signal Analysis** because I want to understand which content characteristics and search signals influence page visibility and engagement. This lane helps identify patterns that can improve search performance and support better content decisions. Instead of simply building a machine learning model, the goal is to understand the relationship between content features and ranking signals so future recommendations are meaningful and actionable.
#                         ^
# SyntaxError: invalid character '–' (U+2013)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one...

# %% [markdown]
# ## The Question
#
# **Decision:** Determine which content characteristics are associated with higher visibility, clicks, and engagement.
#
# **Unit of Analysis:** Individual content page.
#
# **Output:** A ranked list of important ranking signals and insights that influence page performance.
#
# **Action:** Content creators and SEO teams can optimize existing pages and create new content based on the identified ranking signals.
#
# **Cost of a Wrong Recommendation:** If the analysis identifies incorrect signals, valuable pages may be optimized in the wrong way, leading to reduced traffic, lower engagement, and wasted time and resources.
#
# **Why Data or ML Helps:** The dataset contains many pages and performance metrics that are difficult to analyze manually. Data analysis and machine learning can identify meaningful patterns and relationships that support better decision-making.

# %%
## The Question

**Decision:** Determine which content characteristics are associated with higher visibility, clicks, and engagement.

**Unit of Analysis:** Individual content page.

**Output:** A ranked list of important ranking signals and insights that influence page performance.

**Action:** Content creators and SEO teams can optimize existing pages and create new content based on the identified ranking signals.

**Cost of a Wrong Recommendation:** If the analysis identifies incorrect signals, valuable pages may be optimized in the wrong way, leading to reduced traffic, lower engagement, and wasted time and resources.

**Why Data or ML Helps:** The dataset contains many pages and performance metrics that are difficult to analyze manually. Data analysis and machine learning can identify meaningful patterns and relationships that support better decision-making.
# Out:
#   Cell In[4], line 3
#     **Decision:** Determine which content characteristics are associated with higher visibility, clicks, and engagement.
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd 

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nColumn names:")
print(df.columns.tolist())

display(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2
#       3 # Load the starter dataset
# ----> 4 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       5
#       6 print("Rows:", len(df))
#       7 print("Columns:", len(df.columns))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
