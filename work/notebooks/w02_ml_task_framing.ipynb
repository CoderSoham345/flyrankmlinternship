# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CoderSoham345/flyrankmlinternship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My lane as an ML task
#
# I selected **Lane 1 – Ranking Signal Analysis**.
#
# **ML Task Type:** Ranking / Scoring
#
# The objective is to estimate which content pages are likely to perform better in search rankings based on historical engagement and search signals.
#
# This is a ranking problem because the output is an ordered list of pages from highest to lowest expected performance rather than a simple yes/no prediction.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Target or Proxy
#
# The target is the future search ranking performance of a content page.
#
# Since the starter dataset does not contain actual future rankings, I will use engagement metrics such as clicks, impressions, and click-through rate (CTR) as proxy indicators of ranking performance.
#
# Each row in the dataset represents one content page, and the model will estimate which pages are likely to perform better in search results.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Success Metric
#
# The success of the model will be measured by how accurately it ranks content pages according to expected search performance.
#
# Possible evaluation metrics include:
#
# - NDCG (Normalized Discounted Cumulative Gain)
# - Mean Reciprocal Rank (MRR)
# - Spearman Rank Correlation
#
# A better ranking model helps prioritize content updates that are most likely to improve search visibility.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## The Unit of Analysis
#
# The unit of analysis is one content page.
#
# Each row in the dataframe represents one webpage with its associated search performance metrics such as impressions, clicks, CTR, and other ranking signals.
#
# This allows the model to compare pages and estimate which content should be prioritized for optimization.

# %%
import os
import pandas as pd

# Show current working directory
print("Current directory:", os.getcwd())

# Find CSV files
print("\nCSV files found:")
for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# Current directory: c:\Users\Soham\flyrankmlinternship-main\flyrankmlinternship-main\work\notebooks
#
# CSV files found:

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML beats a fixed rule
#
# A fixed rule cannot capture the complex relationships between search ranking signals such as impressions, clicks, CTR, and historical performance.
#
# Machine learning can identify hidden patterns across multiple variables and adapt to new data over time, making ranking predictions more accurate than manually designed rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## Self Check
#
# - ✔ Selected the ML task type
# - ✔ Defined the target/proxy
# - ✔ Explained the success metric
# - ✔ Defined the unit of analysis
# - ✔ Explained why ML is better than fixed rules
# - ✔ Ready for further model development
